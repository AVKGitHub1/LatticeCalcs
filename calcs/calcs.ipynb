# %%
import numpy as np
import matplotlib.pyplot as plt
import arc

# %%
rb = arc.Rubidium85()

# %%
n1,l1,j1 = 5,0,0.5
n2,l2,j2 = 5,1,1.5
t1= rb.getReducedMatrixElementJ(n1,l1,j1,n2,l2,j2)

# %%
n1,l1,j1 = 5,0,0.5
n2,l2,j2 = 6,1,1.5
t2 = rb.getReducedMatrixElementJ(n1,l1,j1,n2,l2,j2)

# %%
t2/t1
# Out:
# np.float64(0.09049395313048861)
